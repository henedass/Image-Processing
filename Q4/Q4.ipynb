# %%
"""
پوشه حاوی تصاویر سوال ۴ را از این لینک دریافت کنید و آنها را در حوزه فرکانس ببرید. لگاریتم قدر مطلق FFT را با استفاده
از fftshift نشان دهید.

"""

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpli

# Function to compute the FFT and plot the logarithm of the absolute value
def fftLog(image_paths):
    plt.figure(figsize=(12, 6))
    for i, path in enumerate(paths, 1):
        # Read the image using matplotlib
        image = mpli.imread(path)

        
        # Convert the image to grayscale if it's in RGB format
        if len(image.shape)== 3 and image.shape[2]== 3:
            image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        
        # Compute the FFT of the image
        f = np.fft.fft2(image)
        fshift = np.fft.fftshift(f)
        
        # Compute the magnitude spectrum and apply logarithm
        magnitudeSpec = np.log(np.abs(fshift) + 1)  # Adding 1 to avoid log(0)
        
        # Plot the original image and its FFT magnitude spectrum
        plt.subplot(2, 2, i)
        plt.imshow(magnitudeSpec, cmap='gray')
        plt.title(f'Log Magnitude Spectrum - Image {i}')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Paths to the images
paths = ['D:\\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.1.jpg',
                'D:\\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.2.jpg', 
                'D:\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.3.jpg', 
                'D:\\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.4.jpg']  # Replace with your image paths

# Apply the function to the images
fftLog(paths)

# %%
D:\\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.1.jpg
D:\\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.2.jpg
D:\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.3.jpg
D:\\sadeneh\\تمرین دوم\\سادنه صادقی- 9913012008\Q4\\4.4.jpg
